# %% [markdown]
# # Linear search
# It is iteration through a loop in a list and finding out the target element and returning the index of the target element.

# %%
nums=[10,15,18,26,0,0,-99,-85,0,36,57,0]

target=-99

for i in range(0,len(nums)-1):
    if nums[i] == target:
        print(i)
        break
# Out:
# 6
